# %% [markdown]
# # **Libraries**

# %%
import tensorflow as tf
from keras.models import Sequential, load_model
from keras.layers import Dense, Input, Softmax, BatchNormalization, Dropout, Conv2D, Flatten, MaxPooling2D, AveragePooling2D, Activation, add, ZeroPadding2D, UpSampling2D, concatenate, Reshape
from keras.losses import CategoricalCrossentropy
from tensorflow.keras.optimizers import RMSprop, Adam, Adamax, Nadam, SGD
from tensorflow.keras import Model
from tensorflow.keras.optimizers.schedules import InverseTimeDecay, ExponentialDecay
from tensorflow.keras.utils import plot_model
from keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import LabelEncoder
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
import seaborn as sns
from copy import deepcopy


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, KFold
from sklearn import metrics
from sklearn.model_selection import KFold


import os
import sys
import time
import cv2 as cv

# %% [markdown]
# **GPU**

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# # **Preprocess**

# %% [markdown]
# ### **Google Drive mount**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/CamVid/"

# %% [markdown]
# ### **Data Visualization**

# %% [markdown]
# #### **random sample**
# (image, segmented image)

# %%
img = np.array(load_img(path + 'test/' + '0001TP_006690.png'))
mask = np.array(load_img(path  + 'test_labels/' + '0001TP_006690_L.png'))

# %% [markdown]
# #### **original shape of data**

# %%
original_input_shape = np.array(img).shape
original_input_shape
# Out:
# (720, 960, 3)

# %% [markdown]
# #### **plotting the original image and its mask**

# %%
fig, arr = plt.subplots(1, 2, figsize=(10, 10))
arr[0].imshow(img)
arr[0].set_title('Image')
arr[1].imshow(mask)
arr[1].set_title('Mask')
# Out:
# Text(0.5, 1.0, 'Mask')

# %% [markdown]
# #### **resize images**

# %%
# scale for resizing images with cv2 library
scale = 0.16666

# %%
# resizing iamge and mask
resized_img = cv.resize(img, (0,0), fx=scale, fy=scale)/255.0
resized_mask = cv.resize(mask, (0,0), fx=scale, fy=scale)
resized_img.shape # resized shape
# Out:
# (120, 160, 3)

# %% [markdown]
# #### **plotting the resized image and its mask**

# %%
fig, arr = plt.subplots(1, 2, figsize=(10, 10))
arr[0].imshow(resized_img)
arr[0].set_title('Image')
arr[1].imshow(resized_mask)
arr[1].set_title('Mask')
# Out:
# Text(0.5, 1.0, 'Mask')

# %% [markdown]
# ### **Feature Adjustment**

# %% [markdown]
# #### **output color classes**

# %%
classes = pd.read_csv(path + 'class_dict.csv', index_col=0) # class name and its rgb color
classes
# Out:
#                      r    g    b
# name
# Animal              64  128   64
# Archway            192    0  128
# Bicyclist            0  128  192
# Bridge               0  128   64
# Building           128    0    0
# Car                 64    0  128
# CartLuggagePram     64    0  192
# Child              192  128   64
# Column_Pole        192  192  128
# Fence               64   64  128
# LaneMkgsDriv       128    0  192
# LaneMkgsNonDriv    192    0   64
# Misc_Text          128  128   64
# MotorcycleScooter  192    0  192
# OtherMoving        128   64   64
# ParkingBlock        64  192  128
# Pedestrian          64   64    0
# Road               128   64  128
# RoadShoulder       128  128  192
# Sidewalk             0    0  192
# SignSymbol         192  128  128
# Sky                128  128  128
# SUVPickupTruck      64  128  192
# TrafficCone          0    0   64
# TrafficLight         0   64   64
# Train              192   64  128
# Tree               128  128    0
# Truck_Bus          192  128  192
# Tunnel              64    0   64
# VegetationMisc     192  192    0
# Void                 0    0    0
# Wall                64  192    0

# %%
n_classes = len(classes) # number of output color classes
n_classes
# Out:
# 32

# %%
classes.index # name of output color classes
# Out:
# Index(['Animal', 'Archway', 'Bicyclist', 'Bridge', 'Building', 'Car',
#        'CartLuggagePram', 'Child', 'Column_Pole', 'Fence', 'LaneMkgsDriv',
#        'LaneMkgsNonDriv', 'Misc_Text', 'MotorcycleScooter', 'OtherMoving',
#        'ParkingBlock', 'Pedestrian', 'Road', 'RoadShoulder', 'Sidewalk',
#        'SignSymbol', 'Sky', 'SUVPickupTruck', 'TrafficCone', 'TrafficLight',
#        'Train', 'Tree', 'Truck_Bus', 'Tunnel', 'VegetationMisc', 'Void',
#        'Wall'],
#       dtype='object', name='name')

# %%
cls2rgb = {cl:list(classes.loc[cl, :]) for cl in classes.index} # dic from class name to its rgb  color

# %%
idx2rgb={idx:np.array(rgb) for idx, (cl, rgb) in enumerate(cls2rgb.items())} # dic from class index to rgb  color

# %% [markdown]
# #### **convert original mask to 32 channel mask and reverse**

# %%
# convert mask to 32 channel image
def adjust_mask(mask, flat=False):
    semantic_map = []
    for colour in list(cls2rgb.values()): # creatingg a channel for each color class
        equality = np.equal(mask, colour) # check equal class color in mask image
        class_map = np.all(equality, axis = -1) # create channel accoording to color equality
        semantic_map.append(class_map) # add created channel
    semantic_map = np.stack(semantic_map, axis=-1)
    return np.float32(semantic_map)

# %%
# map the index back to rgb
def map_class_to_rgb(p):
  return idx2rgb[p[0]]

# %%
# convert back 32 chhannel mask to original shape (3 channel image)
def unadjust_mask(new_mask):
  return np.apply_along_axis(map_class_to_rgb, -1, np.expand_dims(np.argmax(new_mask, axis=-1), -1))

# %%
# convert orgignal mask to 32 channel
new_mask = adjust_mask(resized_mask)
new_mask.shape
# Out:
# (120, 160, 32)

# %%
# convert  back 32 channel mask to original shape
rgb_mask = unadjust_mask(new_mask)
rgb_mask.shape
# Out:
# (120, 160, 3)

# %%
# plotting the conversion processes mask
plt.imshow(rgb_mask)

# %% [markdown]
# ### **Load images**

# %%
images, masks = [], []
for filename in os.listdir(path + 'train/'):
  # read image
  img = np.array(load_img(path + 'train/' + filename))
  # read mask
  mask = np.array(load_img(path + 'train_labels/' + filename[:-4] + '_L.png'))

  if img is not None and mask is not None: # check if non of them is null
    # resizing and normalizing image
    img = cv.resize(mask, (0,0), fx=scale, fy=scale)/255.0

    # resizing mask
    mask = cv.resize(mask, (0,0), fx=scale, fy=scale)
    # converting to 32 channel image
    mask = adjust_mask(mask)

    images.append(img)
    masks.append(mask)

# %% [markdown]
# ### **Feature Selection**

# %%
input_shape = images[0].shape # input shape
input_shape
# Out:
# (120, 160, 3)

# %%
# split data into 90% train set and  10% test set (we split train set into train and valid set whiile fitting the model)
x_train, x_test, y_train, y_test = train_test_split(np.array(images), np.array(masks), test_size=0.1)

# %%
y_test.shape # test set outpuutt shape
# Out:
# (37, 120, 160, 32)

# %%
# train set input and outputt shape
x_train.shape, y_train.shape
# Out:
# ((332, 120, 160, 3), (332, 120, 160, 32))

# %% [markdown]
# # **Model**

# %% [markdown]
# ## **Helper Function**

# %%
def plot_confusionmatrix(y_pred,y_true, classes):
  print('Confusion matrix')
  cf = confusion_matrix(y_pred,y_true)
  sns.heatmap(cf,annot=True,yticklabels=classes, xticklabels=classes, cmap='Blues', fmt='g')
  plt.tight_layout()
  plt.show()

# %%
# plot model results
def showPlots(history):
    plt.plot(history['accuracy'], label='training accuracy', marker='.', color='green')
    plt.plot(history['val_accuracy'], label='validation accuracy', marker='.', color='blue')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

    plt.plot(history['loss'], label='training loss', marker='.', color='red')
    plt.plot(history['val_loss'], label='validation loss', marker='.', color='yellow')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %% [markdown]
# ## **Implementation**

# %%
kernel_size = 7
filter_size = 64
pool_size = 2
height = input_shape[0]
width = input_shape[1]
data_shape = input_shape[0]*input_shape[1]
batch_normalization = True

# %%
inputs = Input(shape=input_shape)
# ------------------------------------ down 1----------------------------------------
conv1 = Conv2D(filter_size, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
if(batch_normalization):
  conv1 = BatchNormalization()(conv1)
pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
# ------------------------------------ down 2 ----------------------------------------
conv2 = Conv2D(2*filter_size, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
if(batch_normalization):
  conv2 = BatchNormalization()(conv2)
pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
# ------------------------------------ down 3 ----------------------------------------
conv3 = Conv2D(4*filter_size, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
if(batch_normalization):
  conv3 = BatchNormalization()(conv3)
pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
# ------------------------------------ down 4 ----------------------------------------
conv4 = Conv2D(8*filter_size, kernel_size, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
if(batch_normalization):
  conv4 = BatchNormalization()(conv4)


# ------------------------------------ up 1 ----------------------------------------
up5 = Conv2D(8*filter_size, 2, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv4)
conv5 = Conv2D(8*filter_size, kernel_size, activation = None , padding = 'same', kernel_initializer = 'he_normal')(up5)
if(batch_normalization):
  conv5 = BatchNormalization()(conv5)
# ------------------------------------ up 2 ----------------------------------------
up6 = Conv2D(4*filter_size, 2, activation = None, padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv5))
conv6 = Conv2D(4*filter_size, kernel_size, activation = None, padding = 'same', kernel_initializer = 'he_normal')(up6)
if(batch_normalization):
  conv6 = BatchNormalization()(conv6)
# ------------------------------------ up 3 ----------------------------------------
up7 = Conv2D(2*filter_size, 2, activation = None, padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
conv7 = Conv2D(2*filter_size, kernel_size, activation = None, padding = 'same', kernel_initializer = 'he_normal')(up7)
if(batch_normalization):
  conv7 = BatchNormalization()(conv7)
# ------------------------------------ up 4 ----------------------------------------
up8 = Conv2D(filter_size, 2, activation = None, padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
conv8 = Conv2D(filter_size, kernel_size, activation = None, padding = 'same', kernel_initializer = 'he_normal')(up8)
if(batch_normalization):
  conv8 = BatchNormalization()(conv8)
# ---------------------------------- output ----------------------------------------
convOut = Conv2D(n_classes, (1,1), padding='same')(conv8)
outputs = Activation('softmax')(convOut)

# %% [markdown]
# ### **without batch norm**

# %%
segnet = Model(inputs, outputs)
segnet.summary()
segnet.compile(optimizer = Adam(learning_rate = 1e-4), loss = 'categorical_crossentropy', metrics = ['accuracy'])
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 120, 160, 3)]     0
#
#  conv2d_13 (Conv2D)          (None, 120, 160, 64)      9472
#
#  batch_normalization_8 (Batc  (None, 120, 160, 64)     256
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 60, 80, 64)       0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 60, 80, 128)       401536
#
#  batch_normalization_9 (Batc  (None, 60, 80, 128)      512
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 30, 40, 128)      0
#  2D)
#
#  conv2d_15 (Conv2D)          (None, 30, 40, 256)       1605888
#
#  batch_normalization_10 (Bat  (None, 30, 40, 256)      1024
#  chNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 15, 20, 256)      0
#  2D)
#
#  conv2d_16 (Conv2D)          (None, 15, 20, 512)       6423040
#
#  batch_normalization_11 (Bat  (None, 15, 20, 512)      2048
#  chNormalization)
#
#  conv2d_17 (Conv2D)          (None, 15, 20, 512)       1049088
#
#  conv2d_18 (Conv2D)          (None, 15, 20, 512)       12845568
#
#  batch_normalization_12 (Bat  (None, 15, 20, 512)      2048
#  chNormalization)
#
#  up_sampling2d_3 (UpSampling  (None, 30, 40, 512)      0
#  2D)
#
#  conv2d_19 (Conv2D)          (None, 30, 40, 256)       524544
#
#  conv2d_20 (Conv2D)          (None, 30, 40, 256)       3211520
#
#  batch_normalization_13 (Bat  (None, 30, 40, 256)      1024
#  chNormalization)
#
#  up_sampling2d_4 (UpSampling  (None, 60, 80, 256)      0
#  2D)
#
#  conv2d_21 (Conv2D)          (None, 60, 80, 128)       131200
#
#  conv2d_22 (Conv2D)          (None, 60, 80, 128)       802944
#
#  batch_normalization_14 (Bat  (None, 60, 80, 128)      512
#  chNormalization)
#
#  up_sampling2d_5 (UpSampling  (None, 120, 160, 128)    0
#  2D)
#
#  conv2d_23 (Conv2D)          (None, 120, 160, 64)      32832
#
#  conv2d_24 (Conv2D)          (None, 120, 160, 64)      200768
#
#  batch_normalization_15 (Bat  (None, 120, 160, 64)     256
#  chNormalization)
#
#  conv2d_25 (Conv2D)          (None, 120, 160, 32)      2080
#
#  activation_1 (Activation)   (None, 120, 160, 32)      0
#
# =================================================================
# Total params: 27,248,160
# Trainable params: 27,244,320
# Non-trainable params: 3,840
# _________________________________________________________________

# %% [markdown]
# ### **with batch norm**

# %%
segnet_bn = Model(inputs, outputs)
segnet_bn.summary()
segnet_bn.compile(optimizer = Adam(learning_rate = 1e-4), loss = 'categorical_crossentropy', metrics = ['accuracy'])
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 120, 160, 3)]     0
#
#  conv2d_13 (Conv2D)          (None, 120, 160, 64)      9472
#
#  batch_normalization_8 (Batc  (None, 120, 160, 64)     256
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 60, 80, 64)       0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 60, 80, 128)       401536
#
#  batch_normalization_9 (Batc  (None, 60, 80, 128)      512
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 30, 40, 128)      0
#  2D)
#
#  conv2d_15 (Conv2D)          (None, 30, 40, 256)       1605888
#
#  batch_normalization_10 (Bat  (None, 30, 40, 256)      1024
#  chNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 15, 20, 256)      0
#  2D)
#
#  conv2d_16 (Conv2D)          (None, 15, 20, 512)       6423040
#
#  batch_normalization_11 (Bat  (None, 15, 20, 512)      2048
#  chNormalization)
#
#  conv2d_17 (Conv2D)          (None, 15, 20, 512)       1049088
#
#  conv2d_18 (Conv2D)          (None, 15, 20, 512)       12845568
#
#  batch_normalization_12 (Bat  (None, 15, 20, 512)      2048
#  chNormalization)
#
#  up_sampling2d_3 (UpSampling  (None, 30, 40, 512)      0
#  2D)
#
#  conv2d_19 (Conv2D)          (None, 30, 40, 256)       524544
#
#  conv2d_20 (Conv2D)          (None, 30, 40, 256)       3211520
#
#  batch_normalization_13 (Bat  (None, 30, 40, 256)      1024
#  chNormalization)
#
#  up_sampling2d_4 (UpSampling  (None, 60, 80, 256)      0
#  2D)
#
#  conv2d_21 (Conv2D)          (None, 60, 80, 128)       131200
#
#  conv2d_22 (Conv2D)          (None, 60, 80, 128)       802944
#
#  batch_normalization_14 (Bat  (None, 60, 80, 128)      512
#  chNormalization)
#
#  up_sampling2d_5 (UpSampling  (None, 120, 160, 128)    0
#  2D)
#
#  conv2d_23 (Conv2D)          (None, 120, 160, 64)      32832
#
#  conv2d_24 (Conv2D)          (None, 120, 160, 64)      200768
#
#  batch_normalization_15 (Bat  (None, 120, 160, 64)     256
#  chNormalization)
#
#  conv2d_25 (Conv2D)          (None, 120, 160, 32)      2080
#
#  activation_1 (Activation)   (None, 120, 160, 32)      0
#
# =================================================================
# Total params: 27,248,160
# Trainable params: 27,244,320
# Non-trainable params: 3,840
# _________________________________________________________________

# %% [markdown]
# ## **Train**

# %% [markdown]
# ### **without batch norm**

# %%
# saving best model based on hihest accuracy on validation set
model_checkpoint = ModelCheckpoint('segnet_camvid.hdf5', monitor='val_accuracy', save_best_only=True)

# %%
with tf.device('/GPU:0'):
  history = segnet.fit(x_train, y_train, validation_split=0.1, epochs=30, batch_size=16, callbacks=[model_checkpoint])
# Out:
# Epoch 1/30
# 19/19 [==============================] - 50s 1s/step - loss: 1.2788 - accuracy: 0.7090 - val_loss: 3.0036 - val_accuracy: 0.6257
# Epoch 2/30
# 19/19 [==============================] - 13s 692ms/step - loss: 0.6807 - accuracy: 0.8171 - val_loss: 1.3599 - val_accuracy: 0.7056
# Epoch 3/30
# 19/19 [==============================] - 8s 425ms/step - loss: 0.5600 - accuracy: 0.8365 - val_loss: 1.1499 - val_accuracy: 0.6868
# Epoch 4/30
# 19/19 [==============================] - 19s 1s/step - loss: 0.4745 - accuracy: 0.8550 - val_loss: 0.9601 - val_accuracy: 0.7365
# Epoch 5/30
# 19/19 [==============================] - 9s 451ms/step - loss: 0.4275 - accuracy: 0.8638 - val_loss: 0.9773 - val_accuracy: 0.7166
# Epoch 6/30
# 19/19 [==============================] - 11s 606ms/step - loss: 0.3904 - accuracy: 0.8715 - val_loss: 0.8371 - val_accuracy: 0.7961
# Epoch 7/30
# 19/19 [==============================] - 13s 716ms/step - loss: 0.3633 - accuracy: 0.8780 - val_loss: 0.7979 - val_accuracy: 0.8136
# Epoch 8/30
# 19/19 [==============================] - 14s 748ms/step - loss: 0.3381 - accuracy: 0.8824 - val_loss: 0.7208 - val_accuracy: 0.8180
# Epoch 9/30
# 19/19 [==============================] - 14s 753ms/step - loss: 0.3121 - accuracy: 0.8885 - val_loss: 0.7181 - val_accuracy: 0.8293
# Epoch 10/30
# 19/19 [==============================] - 14s 732ms/step - loss: 0.2968 - accuracy: 0.8916 - val_loss: 0.6749 - val_accuracy: 0.8366
# Epoch 11/30
# 19/19 [==============================] - 14s 755ms/step - loss: 0.2827 - accuracy: 0.8949 - val_loss: 0.6175 - val_accuracy: 0.8478
# Epoch 12/30
# 19/19 [==============================] - 14s 741ms/step - loss: 0.2760 - accuracy: 0.8965 - val_loss: 0.6175 - val_accuracy: 0.8501
# Epoch 13/30
# 19/19 [==============================] - 14s 775ms/step - loss: 0.2572 - accuracy: 0.9006 - val_loss: 0.5403 - val_accuracy: 0.8612
# Epoch 14/30
# 19/19 [==============================] - 13s 710ms/step - loss: 0.2480 - accuracy: 0.9030 - val_loss: 0.5142 - val_accuracy: 0.8683
# Epoch 15/30
# 19/19 [==============================] - 10s 507ms/step - loss: 0.2406 - accuracy: 0.9044 - val_loss: 0.4799 - val_accuracy: 0.8764
# Epoch 16/30
# 19/19 [==============================] - 8s 442ms/step - loss: 0.2329 - accuracy: 0.9064 - val_loss: 0.4448 - val_accuracy: 0.8743
# Epoch 17/30
# 19/19 [==============================] - 14s 735ms/step - loss: 0.2229 - accuracy: 0.9090 - val_loss: 0.4391 - val_accuracy: 0.8821
# Epoch 18/30
# 19/19 [==============================] - 8s 438ms/step - loss: 0.2180 - accuracy: 0.9101 - val_loss: 0.3874 - val_accuracy: 0.8818
# Epoch 19/30
# 19/19 [==============================] - 14s 728ms/step - loss: 0.2126 - accuracy: 0.9114 - val_loss: 0.3709 - val_accuracy: 0.8870
# Epoch 20/30
# 19/19 [==============================] - 14s 745ms/step - loss: 0.2068 - accuracy: 0.9128 - val_loss: 0.3644 - val_accuracy: 0.8918
# Epoch 21/30
# 19/19 [==============================] - 14s 753ms/step - loss: 0.2014 - accuracy: 0.9143 - val_loss: 0.3481 - val_accuracy: 0.8940
# Epoch 22/30
# 19/19 [==============================] - 19s 1s/step - loss: 0.1965 - accuracy: 0.9156 - val_loss: 0.3336 - val_accuracy: 0.8951
# Epoch 23/30
# 19/19 [==============================] - 14s 730ms/step - loss: 0.1921 - accuracy: 0.9168 - val_loss: 0.3217 - val_accuracy: 0.8964
# Epoch 24/30
# 19/19 [==============================] - 14s 758ms/step - loss: 0.1887 - accuracy: 0.9177 - val_loss: 0.3113 - val_accuracy: 0.8990
# Epoch 25/30
# 19/19 [==============================] - 11s 575ms/step - loss: 0.1861 - accuracy: 0.9187 - val_loss: 0.2895 - val_accuracy: 0.9006
# Epoch 26/30
# 19/19 [==============================] - 8s 440ms/step - loss: 0.1849 - accuracy: 0.9188 - val_loss: 0.2841 - val_accuracy: 0.8982
# Epoch 27/30
# 19/19 [==============================] - 12s 640ms/step - loss: 0.1821 - accuracy: 0.9196 - val_loss: 0.2677 - val_accuracy: 0.9012
# Epoch 28/30
# 19/19 [==============================] - 13s 688ms/step - loss: 0.1773 - accuracy: 0.9211 - val_loss: 0.2817 - val_accuracy: 0.9039
# Epoch 29/30
# 19/19 [==============================] - 14s 743ms/step - loss: 0.1749 - accuracy: 0.9218 - val_loss: 0.2555 - val_accuracy: 0.9040
# Epoch 30/30
# 19/19 [==============================] - 8s 437ms/step - loss: 0.1734 - accuracy: 0.9220 - val_loss: 0.2587 - val_accuracy: 0.9035

# %% [markdown]
# ### **with batch norm**

# %%
# saving best model based on hihest accuracy on validation set
model_checkpoint = ModelCheckpoint('segnet_bn_camvid.hdf5', monitor='val_accuracy', save_best_only=True)

# %%
with tf.device('/GPU:0'):
  history_bn = segnet_bn.fit(x_train, y_train, validation_split=0.1, epochs=40, batch_size=16, callbacks=[model_checkpoint])
# Out:
# Epoch 1/40
# 19/19 [==============================] - 30s 757ms/step - loss: 0.2478 - accuracy: 0.9047 - val_loss: 0.2320 - val_accuracy: 0.8992
# Epoch 2/40
# 19/19 [==============================] - 17s 904ms/step - loss: 0.1936 - accuracy: 0.9159 - val_loss: 0.2237 - val_accuracy: 0.9036
# Epoch 3/40
# 19/19 [==============================] - 19s 1s/step - loss: 0.1770 - accuracy: 0.9209 - val_loss: 0.2255 - val_accuracy: 0.9049
# Epoch 4/40
# 19/19 [==============================] - 9s 453ms/step - loss: 0.1705 - accuracy: 0.9229 - val_loss: 0.2287 - val_accuracy: 0.9048
# Epoch 5/40
# 19/19 [==============================] - 20s 1s/step - loss: 0.1661 - accuracy: 0.9242 - val_loss: 0.2375 - val_accuracy: 0.9054
# Epoch 6/40
# 19/19 [==============================] - 15s 804ms/step - loss: 0.1650 - accuracy: 0.9244 - val_loss: 0.2512 - val_accuracy: 0.9072
# Epoch 7/40
# 19/19 [==============================] - 8s 443ms/step - loss: 0.1633 - accuracy: 0.9251 - val_loss: 0.2385 - val_accuracy: 0.9063
# Epoch 8/40
# 19/19 [==============================] - 19s 1s/step - loss: 0.1592 - accuracy: 0.9261 - val_loss: 0.2386 - val_accuracy: 0.9074
# Epoch 9/40
# 19/19 [==============================] - 14s 776ms/step - loss: 0.1552 - accuracy: 0.9278 - val_loss: 0.2349 - val_accuracy: 0.9087
# Epoch 10/40
# 19/19 [==============================] - 15s 791ms/step - loss: 0.1526 - accuracy: 0.9286 - val_loss: 0.2401 - val_accuracy: 0.9092
# Epoch 11/40
# 19/19 [==============================] - 9s 455ms/step - loss: 0.1510 - accuracy: 0.9290 - val_loss: 0.2427 - val_accuracy: 0.9090
# Epoch 12/40
# 19/19 [==============================] - 8s 441ms/step - loss: 0.1489 - accuracy: 0.9298 - val_loss: 0.2539 - val_accuracy: 0.9089
# Epoch 13/40
# 19/19 [==============================] - 8s 448ms/step - loss: 0.1462 - accuracy: 0.9310 - val_loss: 0.2467 - val_accuracy: 0.9088
# Epoch 14/40
# 19/19 [==============================] - 8s 440ms/step - loss: 0.1426 - accuracy: 0.9322 - val_loss: 0.2438 - val_accuracy: 0.9088
# Epoch 15/40
# 19/19 [==============================] - 8s 438ms/step - loss: 0.1434 - accuracy: 0.9321 - val_loss: 0.2502 - val_accuracy: 0.9080
# Epoch 16/40
# 19/19 [==============================] - 8s 438ms/step - loss: 0.1417 - accuracy: 0.9325 - val_loss: 0.2410 - val_accuracy: 0.9089
# Epoch 17/40
# 19/19 [==============================] - 15s 815ms/step - loss: 0.1410 - accuracy: 0.9328 - val_loss: 0.2476 - val_accuracy: 0.9092
# Epoch 18/40
# 19/19 [==============================] - 8s 434ms/step - loss: 0.1394 - accuracy: 0.9336 - val_loss: 0.2466 - val_accuracy: 0.9083
# Epoch 19/40
# 19/19 [==============================] - 14s 756ms/step - loss: 0.1381 - accuracy: 0.9342 - val_loss: 0.2447 - val_accuracy: 0.9100
# Epoch 20/40
# 19/19 [==============================] - 8s 436ms/step - loss: 0.1358 - accuracy: 0.9347 - val_loss: 0.2398 - val_accuracy: 0.9088
# Epoch 21/40
# 19/19 [==============================] - 8s 440ms/step - loss: 0.1353 - accuracy: 0.9354 - val_loss: 0.2431 - val_accuracy: 0.9096
# Epoch 22/40
# 19/19 [==============================] - 8s 444ms/step - loss: 0.1332 - accuracy: 0.9359 - val_loss: 0.2522 - val_accuracy: 0.9086
# Epoch 23/40
# 19/19 [==============================] - 8s 440ms/step - loss: 0.1316 - accuracy: 0.9366 - val_loss: 0.2427 - val_accuracy: 0.9098
# Epoch 24/40
# 19/19 [==============================] - 8s 438ms/step - loss: 0.1299 - accuracy: 0.9375 - val_loss: 0.2384 - val_accuracy: 0.9092
# Epoch 25/40
# 19/19 [==============================] - 8s 439ms/step - loss: 0.1293 - accuracy: 0.9376 - val_loss: 0.2505 - val_accuracy: 0.9075
# Epoch 26/40
# 19/19 [==============================] - 8s 437ms/step - loss: 0.1286 - accuracy: 0.9380 - val_loss: 0.2400 - val_accuracy: 0.9081
# Epoch 27/40
# 19/19 [==============================] - 8s 436ms/step - loss: 0.1287 - accuracy: 0.9381 - val_loss: 0.2443 - val_accuracy: 0.9091
# Epoch 28/40
# 19/19 [==============================] - 8s 436ms/step - loss: 0.1311 - accuracy: 0.9376 - val_loss: 0.2387 - val_accuracy: 0.9086
# Epoch 29/40
# 19/19 [==============================] - 8s 436ms/step - loss: 0.1289 - accuracy: 0.9380 - val_loss: 0.2365 - val_accuracy: 0.9088
# Epoch 30/40
# 19/19 [==============================] - 8s 435ms/step - loss: 0.1252 - accuracy: 0.9396 - val_loss: 0.2426 - val_accuracy: 0.9095
# Epoch 31/40
# 19/19 [==============================] - 8s 437ms/step - loss: 0.1231 - accuracy: 0.9403 - val_loss: 0.2606 - val_accuracy: 0.9097
# Epoch 32/40
# 19/19 [==============================] - 8s 436ms/step - loss: 0.1220 - accuracy: 0.9413 - val_loss: 0.2480 - val_accuracy: 0.9098
# Epoch 33/40
# 19/19 [==============================] - 8s 439ms/step - loss: 0.1212 - accuracy: 0.9415 - val_loss: 0.2441 - val_accuracy: 0.9090
# Epoch 34/40
# 19/19 [==============================] - 8s 439ms/step - loss: 0.1219 - accuracy: 0.9413 - val_loss: 0.2525 - val_accuracy: 0.9087
# Epoch 35/40
# 19/19 [==============================] - 8s 435ms/step - loss: 0.1217 - accuracy: 0.9418 - val_loss: 0.2534 - val_accuracy: 0.9095
# Epoch 36/40
# 19/19 [==============================] - 8s 439ms/step - loss: 0.1208 - accuracy: 0.9420 - val_loss: 0.2497 - val_accuracy: 0.9096
# Epoch 37/40
# 19/19 [==============================] - 8s 437ms/step - loss: 0.1194 - accuracy: 0.9427 - val_loss: 0.2467 - val_accuracy: 0.9090
# Epoch 38/40
# 19/19 [==============================] - 8s 435ms/step - loss: 0.1189 - accuracy: 0.9432 - val_loss: 0.2538 - val_accuracy: 0.9095
# Epoch 39/40
# 19/19 [==============================] - 8s 437ms/step - loss: 0.1183 - accuracy: 0.9432 - val_loss: 0.2718 - val_accuracy: 0.9090
# Epoch 40/40
# 19/19 [==============================] - 8s 436ms/step - loss: 0.1183 - accuracy: 0.9437 - val_loss: 0.2468 - val_accuracy: 0.9086

# %% [markdown]
# ## **Evaluation**

# %% [markdown]
# ### **without Batch Normalization**

# %% [markdown]
# #### **model results**

# %%
showPlots(history.history)

# %% [markdown]
# #### **best model evaluation**

# %%
# loading best model
segnet = load_model('segnet_camvid.hdf5')

# %%
# evaluate on test set
segnet.evaluate(x_test, y_test, batch_size=32)
# Out:
# 2/2 [==============================] - 11s 2s/step - loss: 0.2878 - accuracy: 0.8938
# [0.28780505061149597, 0.8937992453575134]

# %%
y_pred = segnet.predict(x_test)
# Out:
# 2/2 [==============================] - 1s 204ms/step

# %% [markdown]
# #### **plotting output**

# %%
rgb_mask_pred = unadjust_mask(y_pred[0]) # predicted output
rgb_mask_true = unadjust_mask(y_test[0]) # actual output

# %%
fig, arr = plt.subplots(1, 2, figsize=(10, 10))
arr[0].imshow(rgb_mask_true)
arr[0].set_title('True Mask')
arr[1].imshow(rgb_mask_pred)
arr[1].set_title('Pred Mask')
# Out:
# Text(0.5, 1.0, 'Pred Mask')

# %% [markdown]
# ### **Batch Normalization**

# %% [markdown]
# #### **model results**

# %%
showPlots(history_bn.history)

# %% [markdown]
# #### **best model evaluation**

# %%
# loading best model
segnet_bn = load_model('segnet_bn_camvid.hdf5')

# %%
# evaluate on test set
segnet_bn.evaluate(x_test, y_test, batch_size=32)
# Out:
# 2/2 [==============================] - 1s 71ms/step - loss: 0.2709 - accuracy: 0.9026
# [0.2709466516971588, 0.9026210308074951]

# %%
y_pred = segnet_bn.predict(x_test)
# Out:
# 2/2 [==============================] - 0s 213ms/step

# %% [markdown]
# #### **plotting output**

# %%
rgb_mask_pred = unadjust_mask(y_pred[0]) # predicted output
rgb_mask_true = unadjust_mask(y_test[0]) # actual output

# %%
fig, arr = plt.subplots(1, 2, figsize=(10, 10))
arr[0].imshow(rgb_mask_true)
arr[0].set_title('True Mask')
arr[1].imshow(rgb_mask_pred)
arr[1].set_title('Pred Mask')
# Out:
# Text(0.5, 1.0, 'Pred Mask')
